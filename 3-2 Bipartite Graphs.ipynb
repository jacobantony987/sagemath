# %%
G = graphs.CompleteBipartiteGraph(3,4);
G.bipartite_sets()
# Out:
# ({0, 1, 2}, {3, 4, 5, 6})

# %%
G = graphs.WindmillGraph(4,5); G
# Out:
# Windmill graph Wd(4, 5): Graph on 16 vertices

# %%
G = graphs.ChvatalGraph(); G
# Out:
# Chvatal graph: Graph on 12 vertices
